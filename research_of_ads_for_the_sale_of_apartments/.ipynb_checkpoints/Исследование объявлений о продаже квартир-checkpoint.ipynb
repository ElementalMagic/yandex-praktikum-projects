# %% [markdown]
# # Исследование объявлений о продаже квартир

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-и-задача" data-toc-modified-id="Описание-и-задача-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание и задача</a></span></li><li><span><a href="#Импорт-данных" data-toc-modified-id="Импорт-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Импорт данных</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Расчет-параметров" data-toc-modified-id="Расчет-параметров-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Расчет параметров</a></span><ul class="toc-item"><li><span><a href="#Цена-квадратного-метра" data-toc-modified-id="Цена-квадратного-метра-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Цена квадратного метра</a></span></li><li><span><a href="#День-недели,-месяц-и-год-публикации-объявления" data-toc-modified-id="День-недели,-месяц-и-год-публикации-объявления-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>День недели, месяц и год публикации объявления</a></span></li><li><span><a href="#Этаж-квартиры;-варианты-—-первый,-последний,-другой-и-&quot;неизвестно&quot;-в-тех-случаях,-когда-общее-количество-этажей-или-этаж-квартиры-не-указаны." data-toc-modified-id="Этаж-квартиры;-варианты-—-первый,-последний,-другой-и-&quot;неизвестно&quot;-в-тех-случаях,-когда-общее-количество-этажей-или-этаж-квартиры-не-указаны.-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Этаж квартиры; варианты — первый, последний, другой и "неизвестно" в тех случаях, когда общее количество этажей или этаж квартиры не указаны.</a></span></li><li><span><a href="#Соотношение-жилой-и-общей-площади,-а-также-отношение-площади-кухни-к-общей" data-toc-modified-id="Соотношение-жилой-и-общей-площади,-а-также-отношение-площади-кухни-к-общей-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Соотношение жилой и общей площади, а также отношение площади кухни к общей</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Площадь" data-toc-modified-id="Площадь-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Площадь</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Комнаты" data-toc-modified-id="Комнаты-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Комнаты</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Стоимость" data-toc-modified-id="Стоимость-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Стоимость</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.3.1"><span class="toc-item-num">5.3.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Высота-потолков" data-toc-modified-id="Высота-потолков-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Высота потолков</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.4.1"><span class="toc-item-num">5.4.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Время-продажи-квартиры" data-toc-modified-id="Время-продажи-квартиры-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Время продажи квартиры</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.5.1"><span class="toc-item-num">5.5.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Редкие-и-выбивающиеся-значения" data-toc-modified-id="Редкие-и-выбивающиеся-значения-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Редкие и выбивающиеся значения</a></span><ul class="toc-item"><li><span><a href="#Срок-объявления" data-toc-modified-id="Срок-объявления-5.6.1"><span class="toc-item-num">5.6.1&nbsp;&nbsp;</span>Срок объявления</a></span></li><li><span><a href="#Стоимость-квартир" data-toc-modified-id="Стоимость-квартир-5.6.2"><span class="toc-item-num">5.6.2&nbsp;&nbsp;</span>Стоимость квартир</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.6.3"><span class="toc-item-num">5.6.3&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Какие-факторы-больше-всего-влияют-на-стоимость-квартиры" data-toc-modified-id="Какие-факторы-больше-всего-влияют-на-стоимость-квартиры-5.7"><span class="toc-item-num">5.7&nbsp;&nbsp;</span>Какие факторы больше всего влияют на стоимость квартиры</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.7.1"><span class="toc-item-num">5.7.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#10-населённых-пунктов-с-наибольшим-числом-объявлений" data-toc-modified-id="10-населённых-пунктов-с-наибольшим-числом-объявлений-5.8"><span class="toc-item-num">5.8&nbsp;&nbsp;</span>10 населённых пунктов с наибольшим числом объявлений</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.8.1"><span class="toc-item-num">5.8.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предложения-квартир-в-Санкт-Петербурге" data-toc-modified-id="Предложения-квартир-в-Санкт-Петербурге-5.9"><span class="toc-item-num">5.9&nbsp;&nbsp;</span>Предложения квартир в Санкт-Петербурге</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.9.1"><span class="toc-item-num">5.9.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Сегмент-квартир-в-центре." data-toc-modified-id="Сегмент-квартир-в-центре.-5.10"><span class="toc-item-num">5.10&nbsp;&nbsp;</span>Сегмент квартир в центре.</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.10.1"><span class="toc-item-num">5.10.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# ## Описание и задача

# %% [markdown]
# **Задача**
#
# Используя данные сервиса Яндекс.Недвижимость, определить рыночную стоимость объектов недвижимости и типичные параметры квартир.

# %% [markdown]
# **Описание данных**
#
# * airports_nearest — расстояние до ближайшего аэропорта в метрах (м)
# * balcony — число балконов
# * ceiling_height — высота потолков (м)
# * cityCenters_nearest — расстояние до центра города (м)
# * days_exposition — сколько дней было размещено объявление (от публикации до снятия)
# * first_day_exposition — дата публикации
# * floor — этаж
# * floors_total — всего этажей в доме
# * is_apartment — апартаменты (булев тип)
# * kitchen_area — площадь кухни в квадратных метрах (м²)
# * last_price — цена на момент снятия с публикации
# * living_area — жилая площадь в квадратных метрах(м²)
# * locality_name — название населённого пункта
# * open_plan — свободная планировка (булев тип)
# * parks_around3000 — число парков в радиусе 3 км
# * parks_nearest — расстояние до ближайшего парка (м)
# * ponds_around3000 — число водоёмов в радиусе 3 км
# * ponds_nearest — расстояние до ближайшего водоёма (м)
# * rooms — число комнат
# * studio — квартира-студия (булев тип)
# * total_area — площадь квартиры в квадратных метрах (м²)
# * total_images — число фотографий квартиры в объявлении

# %% [markdown]
# ## Импорт данных

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')

# %%
data.head(10)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1             7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2            10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3             0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4             2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5            10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6             6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7             5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8            20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9            18   5400000.0       61.00  2017-02-26T00:00:00      3
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0            2.70          16.0        51.00      8          NaN   False
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null float64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null object
# rooms                   23699 non-null int64
# ceiling_height          14504 non-null float64
# floors_total            23613 non-null float64
# living_area             21796 non-null float64
# floor                   23699 non-null int64
# is_apartment            2775 non-null object
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            21421 non-null float64
# balcony                 12180 non-null float64
# locality_name           23650 non-null object
# airports_nearest        18157 non-null float64
# cityCenters_nearest     18180 non-null float64
# parks_around3000        18181 non-null float64
# ...

# %%
data['is_apartment'].value_counts()
# Out:
# False    2725
# True       50
# Name: is_apartment, dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Вывод

# %% [markdown]
# * Нужно поменять тип first_day_exposition на Date
# * Нужно заменить тип is_apartment на bool
# * Много пропусков в столбце `ceiling height`, пользователи просто решили не указывать высоту потолков
# * В 90% случаев не указано значение `is_apartment`. Следует воспринимать пустые значения как False
# * В 50% случаев отсутвует данные по количеству балконов. Видимо, балконов в этих квартирах нет
# * Пропуски в `parks_around3000` и `ponds_around3000`, вероятно, указывают на то, что в пределах 3км вокруг этих квартир нет водоёмов или парков
# * Пустые значения в `parks_nearest` и `ponds_nearest` можно объяснить аналогичным образом.
# * Дубликаты отсутствуют

# %% [markdown]
# ## Предобработка данных

# %%
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format='%Y-%m-%d')
data['first_day_exposition'].head(10)
# Out:
# 0   2019-03-07
# 1   2018-12-04
# 2   2015-08-20
# 3   2015-07-24
# 4   2018-06-19
# 5   2018-09-10
# 6   2017-11-02
# 7   2019-04-18
# 8   2018-05-23
# 9   2017-02-26
# Name: first_day_exposition, dtype: datetime64[ns]

# %%
print(data['is_apartment'].value_counts())
data['is_apartment'].fillna(False, inplace=True)
data = data.astype({"is_apartment": bool})
data.head()
# Out:
# False    2725
# True       50
# Name: is_apartment, dtype: int64
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70          16.0         51.0      8         False   False
# 1             NaN          11.0         18.6      1         False   False
# 2             NaN           5.0         34.3      4         False   False
# 3             NaN          14.0          NaN      9         False   False
# 4            3.03          14.0         32.0     13         False   False
#
# ...

# %%
print(data['balcony'].value_counts())
data['balcony'].fillna(0, inplace=True)
print(data['balcony'].value_counts())
data.head()
# Out:
# 1.0    4195
# 0.0    3758
# 2.0    3659
# 5.0     304
# 4.0     183
# 3.0      81
# Name: balcony, dtype: int64
# 0.0    15277
# 1.0     4195
# 2.0     3659
# 5.0      304
# 4.0      183
# 3.0       81
# Name: balcony, dtype: int64
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70          16.0         51.0      8         False   False
# 1             NaN          11.0         18.6      1         False   False
# 2             NaN           5.0         34.3      4         False   False
# ...

# %%
columns = ['parks_around3000', 'ponds_around3000', 'parks_nearest', 'ponds_nearest']
for column in columns:
    before_replacement = data[column].isnull().sum()
    data[column].fillna(0, inplace=True)
    after_replacement = data[column].isnull().sum()
    print('{}:\nБыло пропусков: {}\nСтало: {}\n'.format(column, before_replacement, after_replacement))
data.head()
# Out:
# parks_around3000:
# Было пропусков: 5518
# Стало: 0
#
# ponds_around3000:
# Было пропусков: 5518
# Стало: 0
#
# parks_nearest:
# Было пропусков: 15620
# Стало: 0
#
# ponds_nearest:
# Было пропусков: 14589
# Стало: 0
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70          16.0         51.0      8         False   False
# 1             NaN          11.0         18.6      1         False   False
# 2             NaN           5.0         34.3      4         False   False
# ...

# %%
data['rooms'].value_counts()
# Out:
# 1     8047
# 2     7940
# 3     5814
# 4     1180
# 5      326
# 0      197
# 6      105
# 7       59
# 8       12
# 9        8
# 10       3
# 14       2
# 11       2
# 19       1
# 12       1
# 16       1
# 15       1
# Name: rooms, dtype: int64

# %%
print(data.query('rooms == 0')['rooms'].count())
# Out:
# 197

# %%
data = data.query('rooms > 0 & rooms < 7')
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70          16.0         51.0      8         False   False
# 1             NaN          11.0         18.6      1         False   False
# 2             NaN           5.0         34.3      4         False   False
# 3             NaN          14.0          NaN      9         False   False
# 4            3.03          14.0         32.0     13         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %%
data['rooms'].value_counts()
# Out:
# 1    8047
# 2    7940
# 3    5814
# 4    1180
# 5     326
# 6     105
# Name: rooms, dtype: int64

# %%
data['living_area'].corr(data['total_area'])
# Out:
# 0.9326845153574088

# %%
unique_rooms = data['rooms'].unique()
for rooms_count in data['rooms'].unique():
    print('Число комнат = {}:\n{}'.format(rooms_count, data.query('rooms == @rooms_count')['total_area'].describe()))
    plt.ylabel('Площадь квартиры')
    plt.title('Диаграмма размаха площади для {}-комнатных квартир'.format(rooms_count))
    data.query('rooms == @rooms_count').boxplot('total_area')
   
    data.query('rooms == @rooms_count').hist('total_area', bins=30)
    plt.xlabel('Площадь квартиры')
    plt.ylabel('Частота')
    plt.title('Гистограмма площади {}-комнатных квартир'.format(rooms_count))
    plt.show()
# Out:
# Число комнат = 3:
# count    5814.000000
# mean       77.764580
# std        23.268744
# min        40.100000
# 25%        62.000000
# 50%        73.000000
# 75%        87.000000
# max       363.100000
# Name: total_area, dtype: float64
# Число комнат = 1:
# count    8047.000000
# mean       37.644669
# std         9.338358
# min        12.000000
# 25%        32.500000
# 50%        36.560000
# 75%        41.000000
# max       494.100000
# Name: total_area, dtype: float64
# Число комнат = 2:
# count    7940.000000
# mean       55.855089
# std        13.196340
# min        20.000000
# 25%        46.000000
# 50%        53.000000
# 75%        62.000000
# max       196.000000
# Name: total_area, dtype: float64
# Число комнат = 4:
# count    1180.000000
# mean      107.610763
# std        44.518981
# min        42.000000
# 25%        77.800000
# 50%        99.300000
# 75%       125.325000
# max       500.000000
# Name: total_area, dtype: float64
# Число комнат = 5:
# count    326.000000
# ...

# %%
for rooms_count in unique_rooms:
    data_room = data.query('rooms == @rooms_count')
    
    room_stats = data_room['total_area'].describe()
    Q3_Q1 = room_stats['75%'] - room_stats['25%']
    bottom_limit = room_stats['25%'] - 1.5*Q3_Q1
    top_limit = room_stats['75%'] + 1.5*Q3_Q1
    
    data_room = data_room.query('@bottom_limit <= total_area <= @top_limit')
    data[data['rooms'] == rooms_count] = data_room
    
    print('Число комнат = {}:'.format(rooms_count))
    data.query('rooms == @rooms_count').hist('total_area', bins=30)
    plt.xlabel('Площадь квартиры')
    plt.ylabel('Частота')
    plt.title('Гистограмма скорректированной площади {}-комнатных квартир'.format(rooms_count))
    plt.show()
# Out:
# Число комнат = 3:
# Число комнат = 1:
# Число комнат = 2:
# Число комнат = 4:
# Число комнат = 5:
# Число комнат = 6:

# %%
data = data.dropna(subset=['rooms']).reset_index(drop=True)

# %%
ax = data.plot(kind='hist', y='living_area', histtype='step', range=(0, 150), bins=50,
                              linewidth=1, alpha=0.7, label='living_area')
data.plot(kind='hist', y='total_area', histtype='step', range=(0, 150), bins=50, 
                       linewidth=1, alpha=0.7, label='total_area', ax=ax, grid=True, legend=True)
plt.xlabel('Площадь')
plt.ylabel('Частота')
plt.title('Гистограммы общей и жилой площадей квартир');

# %%
data.query('total_area < 150').plot(x='total_area', y='living_area', kind='scatter', alpha=0.1)
plt.xlabel('Общая площадь')
plt.ylabel('Жилая площадь')
plt.title('Корреляция общей и жилой площадей'.format(rooms_count));

# %%
data.pivot_table(index='rooms', values=['total_area', 'living_area'], aggfunc=['median'])
# Out:
#            median
#       living_area total_area
# rooms
# 1.0         17.50      36.20
# 2.0         30.30      53.00
# 3.0         44.50      72.00
# 4.0         63.00      98.00
# 5.0         90.00     143.00
# 6.0        123.27     181.75

# %%
data.pivot_table(index='rooms', values=['ceiling_height'], aggfunc=['median','mean'])
# Out:
#               median           mean
#       ceiling_height ceiling_height
# rooms
# 1.0             2.60       2.710570
# 2.0             2.60       2.741118
# 3.0             2.65       2.759568
# 4.0             2.80       2.915250
# 5.0             3.10       3.136019
# 6.0             3.20       3.253662

# %%
(data['living_area']
 .fillna(data.groupby('rooms')['living_area']
 .transform('median'), inplace=True))
(data['kitchen_area']
 .fillna(data.groupby('rooms')['kitchen_area']
 .transform('median'), inplace=True))
(data['ceiling_height']
 .fillna(data.groupby('rooms')['ceiling_height']
 .transform('median'), inplace=True))

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0          20.0  13000000.0       108.0           2019-03-07    3.0
# 1           7.0   3350000.0        40.4           2018-12-04    1.0
# 2          10.0   5196000.0        56.0           2015-08-20    2.0
# 3          10.0   2890000.0        30.4           2018-09-10    1.0
# 4           6.0   3700000.0        37.3           2017-11-02    1.0
#
#    ceiling_height  floors_total  living_area  floor is_apartment studio  \
# 0             2.7          16.0         51.0    8.0        False  False
# 1             2.6          11.0         18.6    1.0        False  False
# 2             2.6           5.0         34.3    4.0        False  False
# 3             2.6          12.0         14.4    5.0        False  False
# 4             2.6          26.0         10.6    6.0        False  False
#
#   open_plan  kitchen_area  balcony              locality_name  \
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# Пропускены заполнены:
# * Для расстояния до парков и водоемов - заполнены нулями
# * Для балконов - заполнены нулями
# * Для апартаментов - заполнены False
#
# Были отсечены все квартиры, в которых 0 комнат или больше 6. Таких крайне мало и они не окажут сильного влияния на результаты.
# Были отсечены все выбросы в колонке `total_area` основываясь на диаграмме размаха для квартир с таким же количеством комнат.
# Пропуски в колонках `living_area`, `kitchen_area`, `ceiling_height` были заменены на типовые для квартир с таким же количеством комнат.

# %% [markdown]
# ## Расчет параметров

# %% [markdown]
# ###  Цена квадратного метра

# %%
data['square_meter_price'] = data['last_price'] / data['total_area']

# %% [markdown]
# ### День недели, месяц и год публикации объявления

# %%
data['day_of_week'] = data['first_day_exposition'].dt.dayofweek

# %%
data['month'] = data['first_day_exposition'].dt.month

# %%
data['year'] = data['first_day_exposition'].dt.year

# %% [markdown]
# ### Этаж квартиры; варианты — первый, последний, другой и "неизвестно" в тех случаях, когда общее количество этажей или этаж квартиры не указаны.

# %%
def calc_floor(row):
    skip = (pd.isna(row['floor']) or pd.isna(row['floors_total']))
    if(skip):
        return 'неизвестно'
    else:
        floor = row['floor']
        floors_total = row['floors_total']
        if(floor == floors_total):
            return 'последний'
        elif(floor == 1):
            return 'первый'
        else:
            return 'другой'
    
data['flat_floor'] = data.apply(calc_floor, axis=1)

# %% [markdown]
# ### Соотношение жилой и общей площади, а также отношение площади кухни к общей

# %%
data['living_to_total'] = data['living_area'] / data['total_area']
data['kitchen_to_total'] = data['kitchen_area'] / data['total_area']

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0          20.0  13000000.0       108.0           2019-03-07    3.0
# 1           7.0   3350000.0        40.4           2018-12-04    1.0
# 2          10.0   5196000.0        56.0           2015-08-20    2.0
# 3          10.0   2890000.0        30.4           2018-09-10    1.0
# 4           6.0   3700000.0        37.3           2017-11-02    1.0
#
#    ceiling_height  floors_total  living_area  floor is_apartment studio  \
# 0             2.7          16.0         51.0    8.0        False  False
# 1             2.6          11.0         18.6    1.0        False  False
# 2             2.6           5.0         34.3    4.0        False  False
# 3             2.6          12.0         14.4    5.0        False  False
# 4             2.6          26.0         10.6    6.0        False  False
#
#   open_plan  kitchen_area  balcony              locality_name  \
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# В таблицу были добавлены новые данные:
# * Цена квадратного метра
# * День недели, месяц и год публикации объявления
# * Этаж квартиры
# * Соотношение жилой и общей площади, а также отношение площади кухни к общей

# %% [markdown]
# ## Исследовательский анализ данных

# %%
data.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  22623.000000  2.262300e+04  22623.000000  22623.000000    22623.000000
# mean       9.840958  5.816003e+06     57.619371      2.060293        2.705065
# std        5.647108  5.704734e+06     26.909544      0.990445        0.976951
# min        0.000000  4.300000e+05     20.000000      1.000000        1.000000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.600000
# 50%        9.000000  4.590000e+06     51.000000      2.000000        2.600000
# 75%       14.000000  6.500000e+06     67.800000      3.000000        2.700000
# max       50.000000  2.450000e+08    327.200000      6.000000      100.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  22543.000000  22623.000000  22623.000000  22623.000000  22623.000000
# mean      10.665839     33.159918      5.869558     10.010296      0.589710
# ...

# %% [markdown]
# ### Площадь

# %%
plt.xlabel('Общая площадь квартиры')
plt.title('Гистограмма площади квартир')
data['total_area'].hist(bins=30, range=(20, 200))

# %%
plt.xlabel('Жилая площадь квартиры')
plt.title('Гистограмма жилой площади квартир')
data['living_area'].hist(bins=30, range=(2, 125))

# %%
plt.xlabel('Кухонная площадь квартиры')
plt.title('Гистограмма кухонной площади квартир')
data['kitchen_area'].hist(bins=30, range=(1, 40))

# %%
data.pivot_table(index='rooms', values=['total_area', 'living_area'], aggfunc=['median'])
# Out:
#            median
#       living_area total_area
# rooms
# 1.0         17.50      36.20
# 2.0         30.30      53.00
# 3.0         44.50      72.00
# 4.0         63.00      98.00
# 5.0         90.00     143.00
# 6.0        123.27     181.75

# %%
plt.xlabel('Доля от площади квартиры')
plt.title('Гистограмма жилой площади к общей')
data['living_to_total'].hist(bins=50, range=(0, 1))

# %%
plt.xlabel('Доля от площади квартиры')
plt.title('Гистограмма кухонной площади к общей')
data['kitchen_to_total'].hist(bins=50, range=(0, 0.6))

# %% [markdown]
# #### Вывод

# %% [markdown]
# Медианные значения:
# * Общая площадь квартир = $51 км^2$
# * Жилая площадь = $30 км^2$
# * Кухонная площадь = $9 км^2$
# * Жилая площадь к общей = $56\%$
# * Кухонная площадь к общей = $17\%$
#
# > На гистограммах жилой и кухонной площади имеются пики, которые появились в связи с заменой пропусков медианными значениями.
#
# Больше всего квартир площадью от 40 до 67 квадратных метров. При этом на жилую площадь зачастую приходится половина квартира и еще 17% квартиры занимает кухонная зона.

# %% [markdown]
# ### Комнаты

# %%
plt.xlabel('Количество комнат')
plt.title('Гистограмма количества комнат')
data['rooms'].hist(bins=6, range=(1, 7))

# %%
data['rooms'].value_counts()
# Out:
# 1.0    7800
# 2.0    7707
# 3.0    5575
# 4.0    1134
# 5.0     307
# 6.0     100
# Name: rooms, dtype: int64

# %%
1134 / data['rooms'].count()
# Out:
# 0.050125977987004376

# %% [markdown]
# #### Вывод

# %% [markdown]
# Самыми распространнеными квартирами являются те, где есть 1, 2 или 3 комнаты.
# Количество однокомнатных и двухкомнатных квартир практически совпадает с небольшим перевесом в пользу первых. На долю трехкомнатных квартир приходтся четверть от всех предложений. При этом, доля однокомнатных квартир составляет 34.4%, а двухкомнатных 34%.
# Квартиры с количеством комнат равным 4 и больше являются редкими. Чем больше комнат - тем меньше предложений.

# %% [markdown]
# ### Стоимость

# %%
plt.xlabel('Стоимость квартиры, 10 млн')
plt.title('Гистограмма стоимости квартир')
data['last_price'].hist(bins=100, range=(0, 40000000))

# %%
print('Коэффицент корреляции Пирсона для стоимости и количества комнат в квартире =', data['rooms'].corr(data['last_price']))
print('Коэффицент корреляции Пирсона для стоимости и площади квартиры =', data['total_area'].corr(data['last_price']))
print('Коэффицент корреляции Пирсона для количества комнат и площади квартиры =', data['total_area'].corr(data['rooms']))

data.pivot_table(index='rooms', values=['last_price'], aggfunc=['median','mean'])
# Out:
# Коэффицент корреляции Пирсона для стоимости и количества комнат в квартире = 0.46319237738461794
# Коэффицент корреляции Пирсона для стоимости и площади квартиры = 0.7124959297146918
# Коэффицент корреляции Пирсона для количества комнат и площади квартиры = 0.8197686747230399
#            median          mean
#        last_price    last_price
# rooms
# 1.0     3570000.0  3.706472e+06
# 2.0     4700000.0  5.230536e+06
# 3.0     6000000.0  7.213424e+06
# 4.0     8855000.0  1.175928e+07
# 5.0    13200000.0  1.970630e+07
# 6.0    18075000.0  2.753524e+07

# %% [markdown]
# #### Вывод

# %% [markdown]
# Медианная стоимость составляет 4.6 млн. Видно, как с увеличением количества комнат в квартире увеличивается и стоимость.

# %% [markdown]
# ### Высота потолков

# %%
plt.xlabel('Высота потолков')
plt.title('Гистограмма высоты потолков')
data['ceiling_height'].hist(bins=10, range=(2,4))

# %%
data.pivot_table(index='rooms', values=['ceiling_height'], aggfunc=['median','mean'])
# Out:
#               median           mean
#       ceiling_height ceiling_height
# rooms
# 1.0             2.60       2.663436
# 2.0             2.60       2.686132
# 3.0             2.65       2.721361
# 4.0             2.80       2.879171
# 5.0             3.10       3.125342
# 6.0             3.20       3.238100

# %% [markdown]
# #### Вывод

# %% [markdown]
# Самая распространенная высота потолков среди всех квартир составляет 2.6 метров. С увеличением количества комнат в квартире увеличиваается и высота потолков. Это становится заметно начиная с 3-комнатных квартир.

# %% [markdown]
# ### Время продажи квартиры

# %%
data['days_exposition'].describe()
# Out:
# count    19668.000000
# mean       179.061165
# std        217.223729
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        229.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %%
plt.xlabel('Количество дней от выкладывания объявления до его снятия')
plt.title('Гистограмма длительности объявлений')
data['days_exposition'].hist(bins=30, range=(1, 1000))

# %%
data.pivot_table(index='rooms', values=['days_exposition'], aggfunc=['median','mean'])
# Out:
#                median            mean
#       days_exposition days_exposition
# rooms
# 1.0              80.0      157.824862
# 2.0              90.0      170.610313
# 3.0             113.0      201.343171
# 4.0             155.0      253.669239
# 5.0             174.5      297.038136
# 6.0             220.0      292.887324

# %%
plt.ylabel('Количество дней')
plt.title('Диаграмма размаха длительности размещения объявлений')
data.boxplot(['days_exposition'])

# %% [markdown]
# #### Вывод

# %% [markdown]
# Среднее время сделки составляет 179 дней. Медианное 95 дней. Хочется отметить, что с увеличением комнат в квартире увеличивается мединная продолжительности сделки.
#
# Очень быстрыми сделками я бы считал те сделки, которые произошли за первые 3 дня с момента публикации. А слишком долгими - те, которые выходят за рамки размаха "усов". Т.е., те, чья длительность превышает 505 дней.

# %% [markdown]
# ### Редкие и выбивающиеся значения

# %% [markdown]
# #### Срок объявления

# %%
plt.xlabel('Количество дней от выкладывания объявления до его снятия')
plt.title('Гистограмма длительности объявлений')

data = data.query('not (days_exposition <= 3 | days_exposition >= 505)').reset_index(drop=True)
data['days_exposition'].hist(bins=100, range=(3, 505))

# %% [markdown]
# #### Стоимость квартир

# %%
plt.ylabel('Стоимость квартиры')
plt.title('Диаграмма размаха стоимости квартир')
data.boxplot('last_price')

# %%
data = data.query('last_price < 1.1025*10**7').reset_index(drop=True)

# %% [markdown]
# #### Вывод

# %% [markdown]
# Обнаружил Пуассоновское распределение.
# При этом есть несколько значений (помимо тех, которые я использовал как медианные), которые встречаются значительно чаще остальных. Возможно, это связано с тем, что у бесплатных объявлений есть ограниченный срок размещения и большое количество объявлений о продаже прекращают своё существования по истечению это срока.

# %% [markdown]
# ### Какие факторы больше всего влияют на стоимость квартиры

# %%
data.pivot_table(index='rooms', values=['last_price'], aggfunc=['median','mean']).plot(kind='bar')
plt.ylabel('Стоимость квартиры')
plt.xlabel('Количество комнат')
plt.title('Стоимость квартиры в зависимости от количества комнат');
plt.legend(['Медиана', 'Среднее'])

# %%
print('Коэффицент корреляции Пирсона для стоимости и количества комнат в квартире =', data['rooms'].corr(data['last_price']))
print('Коэффицент корреляции Пирсона для стоимости и площади квартиры =', data['total_area'].corr(data['last_price']))

data.pivot_table(index='rooms', values=['last_price'], aggfunc=['median','mean'])
# Out:
# Коэффицент корреляции Пирсона для стоимости и количества комнат в квартире = 0.4514018749287045
# Коэффицент корреляции Пирсона для стоимости и площади квартиры = 0.6804093036431468
#           median          mean
#       last_price    last_price
# rooms
# 1.0    3550000.0  3.675693e+06
# 2.0    4600000.0  4.901602e+06
# 3.0    5650000.0  5.859759e+06
# 4.0    6700000.0  6.625895e+06
# 5.0    8500000.0  7.898033e+06
# 6.0    9100000.0  8.493778e+06

# %%
data.plot(y='last_price', x='total_area', kind='scatter', alpha=0.3)
plt.ylabel('Стоимость квартиры')
plt.xlabel('Общая площадь квартиры')
plt.title('График корреляции стоимости квартиры и размер общей площади');

# %%
print('Коэффицент корреляции Пирсона для стоимости и приближенности к центру =', data['cityCenters_nearest'].corr(data['last_price']))
# Out:
# Коэффицент корреляции Пирсона для стоимости и приближенности к центру = -0.3374415945708204

# %%
flat_floor_price = data.pivot_table(index='flat_floor', values=['last_price'], aggfunc=['median','mean'])
flat_floor_price.columns = ['median_price', 'mean_price']
flat_floor_price.sort_values('median_price', ascending=True)
# Out:
#             median_price    mean_price
# flat_floor
# первый         3800000.0  4.057214e+06
# последний      3990000.0  4.335947e+06
# другой         4500000.0  4.926070e+06
# неизвестно     4529318.5  4.847492e+06

# %%
for col, name in {'day_of_week': 'день недели', 'month': 'месяц', 'year':'год'}.items():
    table = data.pivot_table(index=col, values=['last_price'], aggfunc=['median','mean'])
    table.columns = ['median_price', 'mean_price']
    display(table.sort_values('median_price', ascending=True))
    table.plot(kind='bar')
    plt.ylabel('Стоимость квартиры')
    plt.xlabel(name)
    plt.legend(['Медиана', 'Среднее'], loc=8)
    plt.show()
# Out:
#              median_price    mean_price
# day_of_week
# 3               4300000.0  4.712628e+06
# 4               4350000.0  4.747034e+06
# 5               4350000.0  4.669425e+06
# 6               4350000.0  4.687890e+06
# 1               4399000.0  4.754075e+06
# 0               4399153.5  4.748999e+06
# 2               4400000.0  4.756845e+06
#        median_price    mean_price
# month
# 6         4150000.0  4.541616e+06
# 5         4300000.0  4.702164e+06
# 7         4300000.0  4.722935e+06
# 10        4300000.0  4.680585e+06
# 1         4350000.0  4.704749e+06
# 2         4350000.0  4.738402e+06
# 8         4350000.0  4.748794e+06
# 9         4350000.0  4.775986e+06
# 12        4390000.0  4.728817e+06
# 3         4400000.0  4.739509e+06
# 11        4450000.0  4.798345e+06
# 4         4500000.0  4.840020e+06
#       median_price    mean_price
# year
# 2016     4220000.0  4.665800e+06
# 2017     4250000.0  4.670411e+06
# 2018     4350000.0  4.694292e+06
# ...

# %% [markdown]
# #### Вывод

# %% [markdown]
# Из моего исследования выше следует, что стоимость квартиры зависит от количества комнат и в большей степени от площади квартиры.
#
# Самыми дешевыми являются квартиры на первом этаже. После них идут квартиры на последнем этаже. Квартиры, которое находятся не на первом и не на последнем этаже значительно дороже остальных.
#
# Связь стоимости и даты подачи объявления:
# * В четверг статистически размещают наиболее дешевые квартиры. Начиная с четверга квартиры начинают дорожать вплоть до среднего максимума в среду.
# * Квартиры, которые размещают на продуже в июне оказываются самыми дешевыми, а в апреле - самыми дорогими.
# * Судя по данным, после 2014 года произошло значительное удешевление квартир, которое усилилиось до 2016 года, и с тех пор они дорожали с каждым годом. В итоге, в 2019 году цены на квартиры превысили цены 2015 года.

# %% [markdown]
# ### 10 населённых пунктов с наибольшим числом объявлений

# %%
top10_regions_names = data['locality_name'].value_counts().head(10).index.tolist()
top10_regions = data.query('locality_name in @top10_regions_names')
top10_regions_grouped = top10_regions.pivot_table(index='locality_name', values=['square_meter_price'], aggfunc=['mean','median'])
top10_regions_grouped.columns = ['mean_price', 'median_price']
display(top10_regions_grouped.sort_values('mean_price', ascending=True))
# Out:
#                       mean_price   median_price
# locality_name
# Выборг              58019.708988   57753.952783
# Всеволожск          67280.671415   65737.874097
# Гатчина             68885.182857   67746.286082
# Колпино             75230.400361   74468.085106
# посёлок Шушары      78515.729311   76747.967480
# посёлок Мурино      85235.185972   84375.000000
# посёлок Парголово   90855.936213   91984.436588
# деревня Кудрово     92327.709794   91569.767442
# Пушкин              99836.372621   98493.150685
# Санкт-Петербург    104788.192232  101562.500000

# %% [markdown]
# #### Вывод

# %% [markdown]
# Наименьшей средней стоимстью квадратного метра, среди 10 крупнейших регионов по количеству объявлений, обладает Выборг. В нем квадратный метр в квартире в среднем стоит 58019.
# Самыми дорогими квардратными метрами обладает Санкт-Петербург. В нем квадратный метр в среднем стоит 104802.
# Разница в средней стоимости квадратного метра между этими двумя регионами составляет 80%.

# %% [markdown]
# ### Предложения квартир в Санкт-Петербурге

# %%
data.loc[:, 'center_km'] = np.ceil(data['cityCenters_nearest'] / 1000)
spb_data = data.query('locality_name == "Санкт-Петербург"')

spb_data.plot(x='center_km', y='last_price', kind='hexbin', sharex=False, gridsize=10)
plt.ylabel('Стоимость квартиры')
plt.xlabel('Расстоние до центра')

spb_data.plot(x='center_km', y='last_price', kind='scatter', alpha=0.3)
plt.ylabel('Стоимость квартиры')
plt.xlabel('Расстоние до центра')
# Out:
# Text(0.5, 0, 'Расстоние до центра')

# %%
print('Коэффициент корреляции Пирсона для стоимости квартиры и удаленности от центра', spb_data['last_price'].corr(spb_data['center_km']))
# Out:
# Коэффициент корреляции Пирсона для стоимости квартиры и удаленности от центра -0.3377753450966906

# %%
spb_km_price = spb_data.pivot_table(index='center_km', values=['last_price'], aggfunc='mean')
spb_km_price.sort_values('last_price', ascending=False)
# Out:
#              last_price
# center_km
# 1.0        8.029212e+06
# 2.0        7.883383e+06
# 5.0        7.434129e+06
# 3.0        7.413816e+06
# 4.0        7.129652e+06
# 6.0        7.129161e+06
# 7.0        6.521227e+06
# 8.0        6.450368e+06
# 21.0       6.291367e+06
# 9.0        6.051675e+06
# 14.0       5.471847e+06
# 13.0       5.291341e+06
# 15.0       5.269527e+06
# 10.0       5.258885e+06
# 12.0       5.248671e+06
# 11.0       5.170828e+06
# 23.0       5.145928e+06
# 16.0       5.105285e+06
# 29.0       5.004375e+06
# 17.0       4.992477e+06
# 22.0       4.979149e+06
# 19.0       4.669671e+06
# 20.0       4.640381e+06
# 18.0       4.624288e+06
# 24.0       4.150769e+06
# 26.0       4.014913e+06
# 25.0       3.862235e+06
# 30.0       3.833333e+06
# 27.0       3.575000e+06
# 28.0       2.250000e+06

# %%
spb_km_price.plot(y='last_price')
plt.ylabel('Стоимость квартир')
plt.xlabel('Расстоние до центра')
plt.title('Средняя стоимость квартир на разном удалении от центра');

# %% [markdown]
# #### Вывод

# %% [markdown]
# Самый большой разрыв в стоимости происходит на расстоянии от 6 до 7 километров. Положим, что центр находится в пределах 6 километров.

# %% [markdown]
# ### Сегмент квартир в центре.

# %%
flats_center = spb_data.query('center_km <= 6')
flats_center['center_km'].value_counts().plot(kind='bar')

# %%
flats_center_summary = flats_center.pivot_table(index='center_km', values=['total_area', 'last_price', 'rooms', 'ceiling_height'])
flats_center_summary
# Out:
#            ceiling_height    last_price     rooms  total_area
# center_km
# 1.0              2.961212  8.029212e+06  2.696970   73.275152
# 2.0              2.940319  7.883383e+06  2.659574   72.771277
# 3.0              3.014610  7.413816e+06  2.500000   68.480455
# 4.0              3.014392  7.129652e+06  2.500000   67.709595
# 5.0              2.896509  7.434129e+06  2.452703   67.344077
# 6.0              2.846746  7.129161e+06  2.263658   63.061354

# %%
flats_center_summary.plot(y='ceiling_height')
plt.ylabel('Высота потолков, метров')
plt.xlabel('Расстоние до центра')
plt.title('Высота потолков в центре');

# %%
flats_center_summary.plot(y='last_price')
plt.ylabel('Стоимость квартир')
plt.xlabel('Расстоние до центра')
plt.title('Стоимость квартир в центре');

# %%
flats_center.plot(x='rooms', y='last_price', kind='scatter', alpha=0.3)
plt.ylabel('Стоимость')
plt.xlabel('Количество комнат')
plt.title('Стоимость квартир от количества комнат');

# %%
flats_center.plot(x='center_km', y='last_price', kind='scatter', alpha=0.3)
plt.ylabel('Стоимость')
plt.xlabel('Удаленность от центра')
plt.title('Стоимость квартир от удаленности от центра');

# %%
flats_center.plot(x='floor', y='last_price', kind='scatter', alpha=0.3)
plt.ylabel('Стоимость')
plt.xlabel('Этаж')
plt.title('Стоимость квартир от этажа');

# %%
flats_center.plot(x='day_of_week', y='last_price', kind='scatter', alpha=0.3)
plt.ylabel('Стоимость')
plt.xlabel('День недели')
plt.title('Стоимость квартир от дня недели размещения объявления');

# %%
flats_center.plot(x='month', y='last_price', kind='scatter', alpha=0.3)
plt.ylabel('Стоимость')
plt.xlabel('Месяц')
plt.title('Стоимость квартир от месяца размещения объявления');

# %%
flats_center.plot(x='year', y='last_price', kind='scatter', alpha=0.3)
plt.ylabel('Стоимость')
plt.xlabel('Год')
plt.title('Стоимость квартир от года размещения объявления');

# %%
flats_center_summary.plot(y='total_area')
plt.ylabel(r'Площадь квартиры, $м^2$')
plt.xlabel('Расстоние до центра')
plt.title('Общая площадь квартиры в центре');

# %%
flats_center[['total_area', 'last_price', 'rooms', 'ceiling_height', 'floor', 'floors_total', 'days_exposition']].describe()
# Out:
#         total_area    last_price        rooms  ceiling_height        floor  \
# count  1442.000000  1.442000e+03  1442.000000     1442.000000  1442.000000
# mean     66.779619  7.323326e+06     2.431345        2.923128     3.577670
# std      22.944820  1.949617e+06     1.020166        0.719425     2.365581
# min      20.000000  1.600000e+06     1.000000        2.400000     1.000000
# 25%      48.000000  5.900000e+06     2.000000        2.600000     2.000000
# 50%      65.150000  7.350000e+06     2.000000        2.800000     3.000000
# 75%      81.100000  8.815000e+06     3.000000        3.100000     5.000000
# max     151.800000  1.100000e+07     6.000000       27.000000    19.000000
#
#        floors_total  days_exposition
# count   1442.000000      1240.000000
# mean       6.287101       144.189516
# std        3.263061       127.427469
# min        2.000000         3.000000
# 25%        5.000000        45.000000
# 50%        5.000000        98.000000
# ...

# %%
spb_data[['total_area', 'last_price', 'rooms', 'ceiling_height', 'floor', 'floors_total', 'days_exposition']].describe()
# Out:
#          total_area    last_price         rooms  ceiling_height         floor  \
# count  12312.000000  1.231200e+04  12312.000000    12312.000000  12312.000000
# mean      53.631365  5.521042e+06      1.970760        2.693328      6.259828
# std       18.271793  1.931649e+06      0.901874        0.715589      4.895130
# min       20.000000  1.200000e+06      1.000000        1.000000      1.000000
# 25%       40.000000  4.000000e+06      1.000000        2.600000      3.000000
# 50%       50.000000  5.050000e+06      2.000000        2.600000      5.000000
# 75%       64.000000  6.690000e+06      3.000000        2.700000      9.000000
# max      183.000000  1.100000e+07      6.000000       27.500000     33.000000
#
#        floors_total  days_exposition
# count  12264.000000     10827.000000
# mean      11.599234       121.903667
# std        6.347614       117.537267
# min        1.000000         3.000000
# 25%        6.000000        35.000000
# 50%        9.000000        78.000000
# ...

# %% [markdown]
# #### Вывод

# %% [markdown]
# Количество квартир в центре обратно пропорционально близости к центру.
# * Высота потолков в квартирах на разном удалении примерно одинаковая
# * Наибольшая стоимость у квартир, которые находятся в пределах 2 километров от центра
# * Чем ближе к центру - тем больше комнат и площадь квартир
#
# По сравнению со всем городом, квартиры в центре:
# * Больше по площади - 66.8 vs 53.6
# * Выше средняя стоимость
# * Имеют больше комнат - 2.4 vs 2
# * Выше потолки - на 20 сантиметров
# * Расположены на более низком этаже и имеют в 2 раза меньше этажей в домах в целом
# * Дольше продаются - вероятно, из-за их стоимости

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Люди, в среднем, продают двухкомнатные квартиры площадью 53 квадртаных метра на 6 этаже. Потолки в квартирах не высокие, но и не низкие - 2.7 м. Дома в основном 11-ти и 12-ти этажные. Среднее время снятия объявление - 120 дней. То есть, за квартиры обычно продают за 4 месяца.
# На стоимость квартир оказывают влияние следующие факторы:
# * Удаленность от центра - квартиры дорожают по мере приближения к центру города
# * Общая площадь - площадь квартиры пропорциональна её стоимости
# * Количество комнат - чем больше комнат, тем дороже квартира
# * На каком этаже расположена квартира - квартиры на первом и последнем этажах стоят дешевле
# * В какой день недели и месяц размещают объявление о продаже - самые дешевые объявления о продаже размещают в четверг в июне
#
# Квартиры в центре ожидаемо дороже, но так же и обладают лучшими параметрами, по сравнению с другими квартирами:
# * Они малоэтажны
# * Больше площадь
# * Выше потолки
# * Имеют больше комнат
